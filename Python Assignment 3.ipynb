# %%
1.What are the two values of the Boolean data type? How do you write them?

There are only two values of Boolean data type and they are: 
    True
    False
    
Here, True has a value of 1 and False has a value of 0. 

2. What are the three different types of Boolean operators?

The three different types of Boolean operators are: 
    1) And Operator (and)
    2) Or Operator (or)
    3) Not Operator (not)


3. Make a list of each Boolean operator's truth tables (i.e. every possible combination of 
   Boolean values for the operator and what it evaluate ).

| Operand 1 | Operand 2 | AND (`and`)          | OR (`or`)         | NOT (`not`)         |
|-----------|-----------|----------------------|-------------------|---------------------|
| True      | True      | True                 | True              | False               |
| True      | False     | False                | True              | False               |
| False     | True      | False                | True              | True                |
| False     | False     | False                | False             | True                |


4. What are the values of the following expressions?

(5 > 4) and (3 == 5)               : False
not (5 > 4)                        : False
(5 > 4) or (3 == 5)                : True
not ((5 > 4) or (3 == 5))          : False
(True and True) and (True == False): False
(not False) or (not True)          : True


5. What are the six comparison operators?

1) Equal to                 : "=="
2) Not Equal to             : "!="
3) Greater than             : ">"
4) Lesser than              : "<"
5) Greater than or equal to : ">="
6) Lesser than or equal to  : "<="
    

6. How do you tell the difference between the equal to and assignment operators? Describe
   a condition and when you would use one.
    
Assignment operators as the name suggests is used to assign a particular value. Typically 
its used to assign a value to a variable. 

Whereas, equal to is a comparison operator, which is used to compare the left hand side to right
hand side and if they are equal to each other returns True as the value or else False. It is
commonly used in conditional statements to check whether a particular statements is correct or not.
    
7. Identify the three blocks in this code:
    
spam = 0
if spam == 10:
print('eggs')
if spam > 5:
print('bacon')
else:
print('ham')
print('spam')
print('spam')

This code has 3 blocks with if and else statements within an if statement. Below I am writing a 
clear code with proper indentation which will show the block of code clearly: 
    
spam = 0
if spam == 10:
    print('eggs')   ## this is the 1st block.
if spam > 5:
    print('bacon')  ## this is the 2nd block. 
else:
    print('ham')
    print('spam')
    print('spam')   ## this is the 3rd block. 
    

8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam,
   and prints Greetings! if anything else is stored in spam.

Spam=int(input())
if Spam ==1:
    print("Hello")
elif Spam ==2:
    print("Howdy")
else: 
    print("Greetings!")

    
9.If your programme is stuck in an endless loop, what keys you’ll press?

I am not sure of keyboard shortcuts, we can press interrupt button (Square button) to interrupt 
running kernel to break an endless loop. Pressing it will instantly break the loop bringing the 
code execution to halt. 

10. How can you tell the difference between break and continue?

The "break" statement is used to break a certain loop. When we have achieved the desired 
objective the loop must come out and end at a certain point. It is then we use break statement. 

The "continue" statement is used to allow the loop to continue ahead executing and parsing 
through the code to continue printing the outputs. 

11. In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?

There is absolutely no difference in any of the three representations of range function. 
By default, the end point for a range is the last number, the beginning is always 0, and step 
size is always +1.

12. Write a short program that prints the numbers 1 to 10 using a for loop. Then write an 
equivalent program that prints the numbers 1 to 10 using a while loop.

for i in range(1,11):
    print(i)
-----------------------
i=1
while i<11: 
    print(i)
    i=i+1

13. If you had a function named bacon() inside a module named spam, how would you call it 
    after importing spam?

import spam
spam.bacon()
