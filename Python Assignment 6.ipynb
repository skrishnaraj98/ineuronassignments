# %%
1. Why are functions advantageous to have in your programs?

Functions helps in reducing repetition and unwanted effort in rewriting a block of code 
thus making the entire code smaller and more efficient just by calling function and executing
it at will to get the desired output. 

2. When does the code in a function run: when it's specified or when it's called?

When a function is called, it is only then the code within a function is executed and not when 
it's specified. 

3. What statement creates a function?

In python, its the "def" statement (shortform for define) which is used to create a function. 

4. What is the difference between a function and a function call?

In this context, a function or defining a function is merely defining the ways that function
will execute upon calling. Whereas a function call is a statement which takes in argument/arguments
and executes the block of code within that function. 

5. How many global scopes are there in a Python program? How many local scopes?

In a Python program, there is only one single global scope and one local scope within a defined
function. 

6. What happens to variables in a local scope when the function call returns?

Local variables dont exist beyond function return. Once a function completes its execution
it flushes out all the storage for local variables so they dont exist after that. 

7. What is the concept of a return value? Is it possible to have a return value in an expression?

The return statement is used within a function to fetch the output of executing a certain 
block of code. This return statement helps in getting an output in the desired format which 
can be reused unlike print statement which returns a NoneType. 

No, return cannot be used for an expression. It can be used only within a function. 

8. If a function does not have a return statement, what is the return value of a call to that 
function?

If there is no return statement within a function, then the return value would be None. 

9. How do you make a function variable refer to the global variable?

We can use "global" prefix before a function variable to refer a global variable. 

10. What is the data type of None?

NoneType is the data type of None. 

11. What does the sentence import areallyourpetsnamederic do?

Upon execution it will throw up ModuleNotFoundError, and that means there is no library or 
a module that exists by this name which can be imported. 

12. If you had a bacon() feature in a spam module, what would you call it after importing spam?

spam.bacon()

13. What can you do to save a programme from crashing if it encounters an error?

If i am using Jupyter Notebook, I can stop the kernel. Or I can restart the kernel. 

14. What is the purpose of the try clause? What is the purpose of the except clause?

The try clause and except clause is part of exception handling which helps Python in handling 
exceptions while executing a code. 
So, the try clause encloses a code block where an exception is expected. 
And except clause is used to handle that exception when it happens and execute the code below it.
