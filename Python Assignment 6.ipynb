# %%
1. What are escape characters, and how do you use them?

Escape characters are special characters which are used within a string to represent some characters which cannot be represented
using the regular characters or methods. For example, using regular characters and methods we cannot represent tabs, backslash,
newline characters, and quotes. 

Some of the most commonly used escape characters are: 
    1. "\n"-new line character
    2. "\t"-tab charactor 
    3. "\\"-Backslash character
    
For example: 
    print("Hello\nWorld")  - Output= Hello
                                     World
    
    print("Hello\tWorld")  - Output= Hello	World
    print("Hello\\World")  - Output= Hello\World

    
2. What do the escape characters n and t stand for?

"\n" - newline character helps strings in representing string in new line from where its used after that. 
"\t" - tab character helps string in displaying a tab between two sections of a string. 


3. What is the way to include backslash characters in a string?

To insert a backlash within a string we can use "\\" backlash character within the string. 
For example: 
    print("Hello\\World")      Output = Hello\World


4. The string "Howl's Moving Castle" is a correct value. Why isn't the single quote character in the word Howl's not 
 escaped a problem?
    
Here's it's not a problem because, the string started with double quotes and so string will only look for the another double 
quotes to consider an end of the string. If the string would have started in single quotes then it would have thrown an Error. 
Since it is within 2 double quotes that's why it has escaped the problem. 
Same is the case with a single double quote within two single quotes. 

For example: print('How you"re doing?')     Output= How you"re doing?
    
    
5. How do you write a string of newlines if you don't want to use the n character?

We can use triple quotes method, and using that we can create any number of new lines. 
For example: 
    print("""How
you're 
doing?""")
    
    Output =
    How
    you're 
    doing?


6. What are the values of the given expressions?
'Hello, world!'[1]    = "e"
'Hello, world!'[0:5]  = "Hello""
'Hello, world!'[:5]   = "Hello"
'Hello, world!'[3:]   = "lo, world!"


7. What are the values of the following expressions?
'Hello'.upper()            = 'HELLO'
'Hello'.upper().isupper()  = True
'Hello'.upper().lower()    = 'hello'


8. What are the values of the following expressions?
'Remember, remember, the fifth of July.'.split()  = ['Remember,', 'remember,', 'the', 'fifth', 'of', 'July.']
'-'.join('There can only one.'.split())           = 'There-can-only-one.'


9. What are the methods for right-justifying, left-justifying, and centering a string?

For example: 
    a="Hello_World"
    a.rjust(20)           Output = '         Hello_World'
    
    a.ljust(20)           Output = 'Hello_World         '
    
    a.center(20)          Output = '    Hello_World     '
    
    
10. What is the best way to remove whitespace characters from the start or end?

For example: 
    a="Hello_World"
    b= a.ljust(20)           Output (b) = 'Hello_World         '
    b.rstrip()               Output     = "Hello_World"
    
    c=a.rjust(20)            Output (c) = '         Hello_World'
    c.lstrip()               Output     = "Hello_World"
